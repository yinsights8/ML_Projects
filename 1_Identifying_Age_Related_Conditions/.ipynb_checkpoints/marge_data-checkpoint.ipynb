# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
warnings.filterwarnings("ignore")
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
# %matplotlib inline

# %%
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'E:\\My_Model\\ML_Projects\\1_Identifying_Age_Related_Conditions': ['.ipynb_checkpoints', 'age_related_conditions.jpg', 'age_related_health_conditions.jpg', 'correlation_1.png', 'correlation_2.png', 'correlation_3.png', 'correlation_4.png', 'data', 'Model Building.ipynb', 'model_EDA.ipynb', 'PS', 'submission.csv', 'Untitled.ipynb']

# %%
path = r"E:/My_Model/ML_Projects/1_Identifying_Age_Related_Conditions/data"

# %%
data = pd.read_csv(f"{path}/train.csv")
data2 = pd.read_csv(f"{path}/greeks.csv")

# %%
data.head()
# Out:
#              Id        AB          AF          AH         AM        AR  \
# 0  000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688
# 1  007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688
# 2  013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688
# 3  043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688
# 4  044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688
#
#          AX        AY         AZ          BC  ...        FL        FR  \
# 0  0.699861  0.025578   9.812214    5.555634  ...  7.298162   1.73855
# 1  3.632190  0.025578  13.517790    1.229900  ...  0.173229   0.49706
# 2  6.732840  0.025578  12.824570    1.229900  ...  7.709560   0.97556
# 3  3.685344  0.025578  11.053708    1.229900  ...  6.122162   0.49706
# 4  3.942255  0.054810   3.396778  102.151980  ...  8.153058  48.50134
#
#          FS         GB          GE            GF         GH         GI  \
# ...

# %%
data2.head()
# Out:
#              Id Alpha Beta Gamma Delta    Epsilon
# 0  000ff2bfdfe9     B    C     G     D  3/19/2019
# 1  007255e47698     A    C     M     B    Unknown
# 2  013f2bd269f5     A    C     M     B    Unknown
# 3  043ac50845d5     A    C     M     B    Unknown
# 4  044fb8a146ec     D    B     F     B  3/25/2020

# %%
print("Shape of the data:- ",data.shape)
print("Shape of the data2:- ",data2.shape)
# Out:
# Shape of the data:-  (617, 58)
# Shape of the data2:-  (617, 6)

# %% [markdown]
# ## Join two dataframs

# %%
df = data.merge(right=data2, how="outer", on="Id")
df.head()
# Out:
#              Id        AB          AF          AH         AM        AR  \
# 0  000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688
# 1  007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688
# 2  013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688
# 3  043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688
# 4  044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688
#
#          AX        AY         AZ          BC  ...            GF         GH  \
# 0  0.699861  0.025578   9.812214    5.555634  ...   2003.810319  22.136229
# 1  3.632190  0.025578  13.517790    1.229900  ...  27981.562750  29.135430
# 2  6.732840  0.025578  12.824570    1.229900  ...  13676.957810  28.022851
# 3  3.685344  0.025578  11.053708    1.229900  ...   2094.262452  39.948656
# 4  3.942255  0.054810   3.396778  102.151980  ...   8524.370502  45.381316
#
#           GI         GL  Class  Alpha  Beta  Gamma  Delta    Epsilon
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 63 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       617 non-null    object
#  1   AB       617 non-null    float64
#  2   AF       617 non-null    float64
#  3   AH       617 non-null    float64
#  4   AM       617 non-null    float64
#  5   AR       617 non-null    float64
#  6   AX       617 non-null    float64
#  7   AY       617 non-null    float64
#  8   AZ       617 non-null    float64
#  9   BC       617 non-null    float64
#  10  BD       617 non-null    float64
#  11  BN       617 non-null    float64
#  12  BP       617 non-null    float64
#  13  BQ       557 non-null    float64
#  14  BR       617 non-null    float64
#  15  BZ       617 non-null    float64
#  16  CB       615 non-null    float64
#  17  CC       614 non-null    float64
#  18  CD       617 non-null    float64
#  19  CF       617 non-null    float64
# ...

# %%
df.to_csv(f"{path}/megadata.csv")
